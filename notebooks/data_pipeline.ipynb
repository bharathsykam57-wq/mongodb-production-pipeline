# %%
import sys
print(sys.executable)
print(sys.version)
import pandas as pd
print(pd.__version__)
import numpy as np
print(np.__version__)
# Out:
# /Users/sykambharath/mongo_production_app/venv/bin/python
